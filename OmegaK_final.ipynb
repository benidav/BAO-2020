# %% [markdown]
# <h3>File written by David Benisty and Denitsa Staicova</h3> If you use it or parts of it, please cite <a href="https://arxiv.org/abs/2009.10701"> arXiv:2009.10701 [astro-ph.CO]</a><br>
# Title: OmegaK-CDM v.1 <br>
# Last update: 15.12.2020

# %%
                                                                                                                                        from numpy import pi, log, sqrt
import emcee
import getdist
import numpy as np
from io import StringIO 
from getdist import plots, MCSamples
import random
from scipy.integrate import quad
from scipy.integrate import odeint
import scipy.integrate as integrate
import matplotlib.pyplot as plt
from scipy import stats 
import pypolychord
from pypolychord.settings import PolyChordSettings
from pypolychord.priors import UniformPrior, GaussianPrior
import scipy.optimize as op
from numpy.linalg import inv
from mpi4py import MPI

# %%
# load Cosmic Chronometers dataset
ccData = np.genfromtxt("./BAO/CC.txt")
# load Pantheon dataset
panthData = np.genfromtxt("./BAO/binned_data.txt")
panthData = panthData[np.argsort(panthData[:,1])]
# load GRB dataset
GRBData = np.genfromtxt("./BAO/GRB.txt")
# load Quzars
QuData = np.genfromtxt("./BAO/Quasars.txt")


#loading BAO data
dirBD= "./BAO/uncorBAO.txt"
#dirDJ= "./BAO/data.txt"
BaoData = np.genfromtxt(dirBD)
xarr = np.array(BaoData[:,0])    
yarr = np.array(BaoData[:,1])
dyarr = np.array(BaoData[:,2])

funarr = np.genfromtxt(dirBD,dtype='str')[:,3]
print(funarr)

def modelArr(name):
    mod = []

    for j in range(len(funarr)):
        if (funarr[j] == name):
             mod.append([xarr[j],yarr[j],dyarr[j]])
    mod = np.array(mod)
    mod = mod[np.argsort(mod[:,0])]
    return mod
# Out:
# ['DVratio' 'DVratio' 'DArd' 'rdDV' 'DVratio' 'DArd' 'DVratio' 'Hxrd'
#  'DVrd' 'rdDV' 'DHrd' 'rdDV' 'rdDV' 'rdDV' 'DHrd' 'DAratio' 'DAratio']

# %%
#H functions
c = 299792.458

def E(theta,z):
    H0, Ok, Om, Ol, rd, rat = theta
    return np.sqrt(np.abs(Om*(1+z)**3 + Ol + Ok*(1+z)**2+(1 - Om - Ol - Ok)*(1+z)**4))

def H(theta,z):
    H0, Ok, Om, Ol, rd, rat = theta
    arr = []
    
    for j in range(len(z)):
        arr.append(H0*E(theta,z[j]))
    arr = np.array(arr)
    return arr

def Hxrd(theta,z):
    H0, Ok, Om, Ol, rd, rat = theta
    arr = []
    
    for j in range(len(z)):
        arr.append(rd*H0*E(theta,z[j]))
    arr = np.array(arr)
    return arr

def Hxratio(theta,z):
    H0, Ok, Om, Ol, rd, rat = theta
    arr = []
    
    for j in range(len(z)):
        arr.append(H0*E(theta,z[j])*rat)
    arr = np.array(arr)
    return arr

Hxratio([67,0.007,0.31,0.67,150,1],[1,2,3])
# Out:
# array([123.28728239, 213.51881416, 327.88953933])

# %%
#DH functions
def DH(theta,z):
    H0, Ok, Om, Ol, rd, rat = theta
    arr = []
    
    for j in range(len(z)):
        arr.append(c/(H0*E(theta,z[j])))
    arr = np.array(arr)
    return arr

def DHrd(theta,z):
    H0, Ok, Om, Ol, rd, rat = theta
    arr = []
    
    for j in range(len(z)):
        arr.append(c/(H0*E(theta,z[j])*rd))
    arr = np.array(arr)
    return arr

DHrd([67,0.007,0.31,0.67,150,1],[1,2,3])
# Out:
# array([16.21105071,  9.36037601,  6.09539539])

# %%
def Sk(theta,x):
    H0, Ok, Om, Ol, rd, rat = theta
    if Ok < -10**(-15):
        return np.sin(np.sqrt(-Ok)*x)/np.sqrt(-Ok)
    #if Ok == 0:
    #    return x
    elif Ok > 10**(-15):
        return np.sinh(np.sqrt(Ok)*x)/np.sqrt(Ok)
    else:
        return x

# %%
# function that returns dDC/dz,df/dz
def dchidz(x,z, H0, Ok, Om, Ol, rd, rat):
    return 1/E([H0, Ok, Om, Ol, rd, rat],z)

def chiInt(theta,z):
    H0, Ok, Om, Ol, rd, rat = theta 
    z = np.hstack((np.array((0)), z))
    arr = odeint(dchidz,0,z,args=(H0, Ok, Om, Ol, rd, rat,))
    return np.delete(arr ,0)

chiInt([67,0.007,0.31,0.67,150,1],[1,2,3])
# Out:
# array([0.75518797, 1.16872242, 1.42173239])

# %%
#DM 

def DM(theta,z):
    H0, Ok, Om, Ol, rd, rat = theta 
    chi = chiInt(theta,z)
    
    arr = []
    
    for i in range(len(z)):
        arr.append(c*Sk(theta,chi[i])/H0)
    arr = np.array(arr)
    arr.shape
    return arr

def DMrd(theta,z):
    H0, Ok, Om, Ol, rd, rat = theta
    chi = chiInt(theta,z)
    
    arr = []
    
    for i in range(len(z)):
        arr.append(c*Sk(theta,chi[i])/(H0*rd))
    arr = np.array(arr)
    arr.shape
    return arr

def DMratio(theta,z):
    H0, Ok, Om, Ol, rd, rat = theta 
    chi = chiInt(theta,z)
    
    arr = []
    
    for i in range(len(z)):
        arr.append(c*Sk(theta,chi[i])/(H0*rat))
    arr = np.array(arr)
    arr.shape
    return arr

DMratio([67,0.007,0.31,0.67,150,1],[1,2,3])
# Out:
# array([3381.34812834, 5237.80263671, 6376.5744424 ])

# %%
#DA 

def DA(theta,z):
    H0, Ok, Om, Ol, rd, rat = theta 
    chi = chiInt(theta,z)
    
    arr = []
    
    for i in range(len(z)):
        arr.append(c*Sk(theta,chi[i])/(H0*(z[i]+1)))
    arr = np.array(arr)
    arr.shape
    return arr

def DArd(theta,z):
    H0, Ok, Om, Ol, rd, rat = theta 
    chi = chiInt(theta,z)
    
    arr = []
    
    for i in range(len(z)):
        arr.append(c*Sk(theta,chi[i])/(H0*rd*(z[i]+1)))
    arr = np.array(arr)
    arr.shape
    return arr

def DAratio(theta,z):
    H0, Ok, Om, Ol, rd, rat = theta 
    chi = chiInt(theta,z)
    
    arr = []
    
    for i in range(len(z)):
        arr.append(c*Sk(theta,chi[i])/(H0*rat*(z[i]+1)))
    arr = np.array(arr)
    arr.shape
    return arr

DAratio([67,0.007,0.31,0.67,150,1],[1,2,3])
# Out:
# array([1690.67406417, 1745.93421224, 1594.1436106 ])

# %%
#DV 

def DV(theta,z):
    H0, Ok, Om, Ol, rd, rat = theta 
    dh = DH(theta,z)  
    dm = DM(theta,z)
    arr = []
    
    for i in range(len(z)):
        arr.append(np.cbrt(z[i]*dh[i]*dm[i]**2))
    arr = np.array(arr)
    arr.shape
    return arr

def DVrd(theta,z):
    H0, Ok, Om, Ol, rd, rat = theta 
    dh = DH(theta,z)  
    dm = DM(theta,z)
    arr = []
    
    for i in range(len(z)):
        arr.append(np.cbrt(z[i]*dh[i]*dm[i]**2)/rd)
    arr = np.array(arr)
    arr.shape
    return arr

def DVratio(theta,z):
    H0, Ok, Om, Ol, rd, rat = theta
    dh = DH(theta,z)  
    dm = DM(theta,z)
    arr = []
    
    for i in range(len(z)):
        arr.append(np.cbrt(z[i]*dh[i]*dm[i]**2)/rat)
    arr = np.array(arr)
    arr.shape
    return arr

def rdDV(theta,z):
    H0, Ok, Om, Ol, rd, rat = theta
    dh = DH(theta,z)  
    dm = DM(theta,z)
    arr = []
    
    for i in range(len(z)):
        arr.append(rd/(np.cbrt(z[i]*dh[i]*dm[i]**2)))
    arr = np.array(arr)
    arr.shape
    return arr

rdDV([67,0.007,0.31,0.67,150,1],[1,2,3])
# Out:
# array([0.04951429, 0.03525226, 0.0311622 ])

# %%
def mu(theta,z):
    DL = DM(theta,z)    
    mu = []
    
    for i in range(len(z)):
        mu.append(5*np.log10(DL[i]*(1+z[i])))
    mu = np.array(mu)
    mu.shape
    return mu

# %%
def lnlike(theta, model,x,y,dy):
    num = len(x)
    chi2 = 0 
    
    prediction = model(theta,x)
    for i in range(len(x)):
        chi2 += ((prediction[i]-y[i])/dy[i])**2
    return chi2

def lnlikeCC(theta):
    chi = 0; i = 0
    chi += lnlike(theta,H,ccData[:,0], ccData[:,1], ccData[:,2]); i += len(ccData[:,0])
    return -chi, [i, chi/(i-len(theta)),1-stats.chi2.cdf(x=chi, df=(i-len(theta)))]

print(lnlikeCC([67,0.007,0.31,0.67,150,1]))
# Out:
# (-14.775753990198728, [30, 0.6156564162582804, 0.9271488970070771])

# %%
# biuld the covariance matrix
def covFromErr(error):
    num = len(error)
    cov = np.zeros((num,num))
    for j in range(num):
        cov[j,j] = error[j]**2
    return inv(cov)

def randCov(list_length,error):
    num = len(error)
    cov = np.zeros((num,num))
    for j in range(num):
        cov[j,j] = error[j]**2
    # the covariance matrix for the uncorrelated data
    randomList = random.sample(range(len(error)), list_length)
    for i in range(len(randomList)):
        for j in range(len(randomList)):
            if (i!=j):
                cov[i,j] += 0.5*error[i]*error[j]               
    return inv(cov)

# %%
# likelihood with covariance matrix
def lnlikecov(theta,model,x,y,cov):
    chi2 = 0 
    prediction = []
    #x = x*np.ones(len(model))
    for i in range(len(model)):
        fun = model[i]
        prediction.append(eval(fun)(theta,[x[i]]))
    prediction = np.array(prediction)[:,0]
    prediction.shape
    vec = (prediction - y)
    
    result = np.dot(np.dot(vec,cov),vec.T)
    return result

numUn = 0

print(lnlikecov([67,0.007,0.31,0.67,150,1],funarr,np.array(BaoData[:,0]),np.array(BaoData[:,1]),covFromErr(np.array(BaoData[:,2]))))
print(lnlikecov([67,0.007,0.31,0.67,150,1],funarr,np.array(BaoData[:,0]),np.array(BaoData[:,1]),randCov(numUn,np.array(BaoData[:,2]))))
# Out:
# 25.728502243478285
# 25.728502243478285

# %%
def lnlikeBAO(theta):
    chi =  lnlikecov(theta,funarr,np.array(BaoData[:,0]),np.array(BaoData[:,1]),covFromErr(np.array(BaoData[:,2]))) 
    i = len(BaoData[:,0])
    return -chi, [chi, chi/(i-len(theta)),1-stats.chi2.cdf(x=chi, df=(i-len(theta)))]

lnlikeBAO([68,0.007,0.31,0.68,147,0.9])
# Out:
# (-83.60622240180729,
#  [83.60622240180729, 7.600565672891571, 2.949862576429041e-13])

# %%
#The likelihood functions
def A(theta, x, y, yerr):
    chi2 = 0
    Mu = mu(theta,x)
    for i in range(len(x)):
        chi2 += (y[i] - Mu[i])**2/yerr[i]**2
    return chi2

def B(theta, x, y, yerr):
    chi2 = 0
    Mu = mu(theta,x)
    for i in range(len(x)):
        chi2 += (y[i] - Mu[i])/yerr[i]**2
    return chi2

def C(theta, x, y, yerr):
    chi2 = 0
    for i in range(len(x)):
        chi2 += 1/yerr[i]**2
    return chi2

def chiTyIA(theta, x, y, yerr):
    return (A(theta, x, y, yerr) - B(theta, x, y, yerr)**2/C(theta, x, y, yerr))

def lnlikeHubb(theta):
    chi = chiTyIA(theta,panthData[:,1], panthData[:,4], panthData[:,5])
    chi += chiTyIA(theta,GRBData[:,2],GRBData[:,3],GRBData[:,4])
    chi += chiTyIA(theta,QuData[:,0],QuData[:,1],QuData[:,2])
    i = len(panthData[:,1]) + len(GRBData[:,2]) + len(QuData[:,0])
    return -chi, [chi, chi/(i-len(theta)),1-stats.chi2.cdf(x=chi, df=(i-len(theta)))]

print(lnlikeHubb([68,0.007,0.31,0.68,147,0.9]))
# Out:
# (-236.52448168485716, [236.52448168485716, 1.0751112803857144, 0.21172029961563565, 226])

# %%
def lnlikeTot(theta):
    chi =  lnlikecov(theta,funarr,np.array(BaoData[:,0]),np.array(BaoData[:,1]),covFromErr(np.array(BaoData[:,2]))) 
    i = len(BaoData[:,0])
    chi += lnlike(theta,H,ccData[:,0], ccData[:,1], ccData[:,2]); i += len(ccData[:,0])  
    chi += chiTyIA(theta,panthData[:,1], panthData[:,4], panthData[:,5])
    chi += chiTyIA(theta,GRBData[:,2],GRBData[:,3],GRBData[:,4])
    chi += chiTyIA(theta,QuData[:,0],QuData[:,1],QuData[:,2])
    i += len(panthData[:,1]) + len(GRBData[:,2]) + len(QuData[:,0]) 
    return -chi, [chi, chi/(i-len(theta)),1-stats.chi2.cdf(x=chi, df=(i-len(theta)))]

print(lnlikeTot([68,0.007,0.31,0.68,147,0.9]))
# Out:
# (-334.66185189271516, [334.66185189271516, 1.2534151756281466, 0.0030708211840181354, 273])

# %%
runs = 100

# %%
def dumper(live, dead, logweights, logZ, logZerr):
    print("Last dead point:", dead[-1])

# %%
def uniprior(hypercube):
    prior = []
    prior.append(UniformPrior(50.,100.)(hypercube[0]))
    prior.append(UniformPrior(-0.1,0.1)(hypercube[1])) #k
    prior.append(UniformPrior(0.1,1.-hypercube[1])(hypercube[2]))
    prior.append(UniformPrior(0.,1-hypercube[2])(hypercube[3]))
    prior.append(UniformPrior(100,200)(hypercube[4]))
    prior.append(UniformPrior(0.9,1.1)(hypercube[5]))
    return prior

def unipriorRiess(hypercube):
    prior = []
    prior.append(GaussianPrior(74.03,1.42)(hypercube[0]))
    prior.append(UniformPrior(-0.1,0.1)(hypercube[1])) #k
    prior.append(UniformPrior(0.1,1.-hypercube[1])(hypercube[2]))
    prior.append(UniformPrior(0.,1-hypercube[2])(hypercube[3]))
    prior.append(UniformPrior(100,200)(hypercube[4]))
    prior.append(UniformPrior(0.9,1.1)(hypercube[5]))
    return prior

# %%
settingsBAO = PolyChordSettings(6,3)
settingsBAO.file_root = 'LCDMBAO_OmkNcS100'
settingsBAO.nlive = runs
settingsBAO.do_clustering = True
settingsBAO.read_resume = False

settingsBAOR = PolyChordSettings(6,3)
settingsBAOR.file_root = 'LCDMBAOR_OmkNcS100'
settingsBAOR.nlive = runs
settingsBAOR.do_clustering = True
settingsBAOR.read_resume = False

settingsHDR = PolyChordSettings(6,3)
settingsHDR.file_root = 'LCDMHDR_OmkNcS100'
settingsHDR.nlive = runs
settingsHDR.do_clustering = True
settingsHDR.read_resume = False

settingsTot = PolyChordSettings(6,3)
settingsTot.file_root = 'LCDMTot_OmkNcS100'
settingsTot.nlive = runs
settingsTot.do_clustering = True
settingsTot.read_resume = False

settingsTotR = PolyChordSettings(6,3)
settingsTotR.file_root = 'LCDMTotR_OmkNcS100'
settingsTotR.nlive = runs
settingsTotR.do_clustering = True
settingsTotR.read_resume = False

# %%
outputBAO = pypolychord.run_polychord(lnlikeBAO, 6,3, settingsBAO, uniprior, dumper)
# Out:
# Last dead point: [ 6.27219328e+01 -1.25442620e-02  3.20475737e-01  4.85047285e-01
#   1.97582476e+02  1.07692992e+00  2.70438992e+03  2.45853629e+02
#   0.00000000e+00 -8.42828112e+03 -2.70438992e+03]
# Last dead point: [ 5.10053128e+01  3.11903329e-03  2.22000933e-01  5.22466580e-01
#   1.75993777e+02  9.06967485e-01  1.14852272e+03  1.04411157e+02
#   0.00000000e+00 -1.29837824e+03 -1.14852272e+03]
# Last dead point: [ 5.74354293e+01 -8.95875830e-03  3.72476665e-01  2.75331061e-01
#   1.24401807e+02  1.01545966e+00  7.16544666e+02  6.51404242e+01
#   0.00000000e+00 -1.14783422e+03 -7.16544666e+02]
# Last dead point: [ 8.81658692e+01 -2.00124319e-02  1.66325082e-01  8.53384834e-01
#   1.44512705e+02  1.02423033e+00  4.26664665e+02  3.87876969e+01
#   0.00000000e+00 -7.17649726e+02 -4.26664665e+02]
# Last dead point: [ 6.40105326e+01  1.82800854e-02  1.84422770e-01  6.77414639e-01
#   1.49886224e+02  9.20617107e-01  2.56064267e+02  2.32785697e+01
#   0.00000000e+00 -3.21760926e+02 -2.56064267e+02]
# Last dead point: [ 6.58259250e+01  4.46756825e-02  1.15181179e-01  8.23407417e-01
#   1.76410197e+02  1.00859497e+00  1.40267103e+02  1.27515549e+01
#   0.00000000e+00 -2.10168437e+02 -1.40267103e+02]
# Last dead point: [ 7.09786129e+01 -3.28473574e-02  1.80433492e-01  8.27127696e-01
#   1.61849161e+02  1.02081025e+00  7.54394005e+01  6.85812732e+00
#   1.11624043e-11 -9.06381609e+01 -7.54394005e+01]
# Last dead point: [ 6.69009976e+01 -5.43058936e-02  1.87915542e-01  8.61094156e-01
#   1.67625764e+02  1.06316208e+00  5.00456160e+01  4.54960145e+00
#   6.14230685e-07 -6.36555083e+01 -5.00456160e+01]
# Last dead point: [ 7.29974025e+01  9.81448671e-02  7.89433718e-02  7.52358723e-01
#   1.43208163e+02  9.54233599e-01  3.41704767e+01  3.10640697e+00
#   3.39187657e-04 -4.94602214e+01 -3.41704767e+01]
# Last dead point: [ 7.26042313e+01  5.36215953e-02  1.27469118e-01  7.70540192e-01
#   1.39157142e+02  9.64118898e-01  2.55890372e+01  2.32627611e+00
#   7.46771447e-03 -2.66807402e+01 -2.55890372e+01]
# Last dead point: [ 6.52876248e+01 -5.94171469e-02  2.25043926e-01  7.99792565e-01
#   1.55575801e+02  1.07818477e+00  2.03721647e+01  1.85201497e+00
#   4.04904680e-02 -2.35254573e+01 -2.03721647e+01]
# Last dead point: [ 7.32670674e+01 -7.06788807e-02  2.36451934e-01  8.11749332e-01
#   1.41989314e+02  9.31932639e-01  1.73253552e+01  1.57503229e+00
#   9.86132678e-02 -1.76246025e+01 -1.73253552e+01]
# Last dead point: [ 7.64759473e+01  8.35639594e-02  9.67804866e-02  7.74221516e-01
#   1.38154170e+02  9.20657903e-01  1.54657449e+01  1.40597681e+00
#   1.62151991e-01 -1.70311721e+01 -1.54657449e+01]
# Last dead point: [ 6.64142484e+01  9.37972692e-02  9.91358276e-02  7.64063951e-01
#   1.60242818e+02  1.07143069e+00  1.41501736e+01  1.28637942e+00
#   2.24794882e-01 -1.55491500e+01 -1.41501736e+01]
# Last dead point: [ 7.82247343e+01 -2.38785196e-04  1.67313439e-01  8.04952838e-01
#   1.35113345e+02  9.14286553e-01  1.30840504e+01  1.18945913e+00
#   2.87867446e-01 -1.38165118e+01 -1.30840504e+01]
# Last dead point: [ 6.83092475e+01 -3.14820652e-04  1.70483523e-01  7.98317882e-01
#   1.54435305e+02  1.03502103e+00  1.24318342e+01  1.13016675e+00
#   3.32073797e-01 -1.32315455e+01 -1.24318342e+01]
# Last dead point: [ 6.70693048e+01 -9.83323986e-02  2.36723363e-01  8.46106246e-01
#   1.58858251e+02  1.06046020e+00  1.19512566e+01  1.08647788e+00
#   3.67318250e-01 -1.23805302e+01 -1.19512566e+01]
# Last dead point: [ 6.63624743e+01 -7.68943072e-02  2.46921005e-01  8.12122873e-01
#   1.57783391e+02  1.06688323e+00  1.15514444e+01  1.05013131e+00
#   3.98285411e-01 -1.20858999e+01 -1.15514444e+01]
# Last dead point: [ 7.36336549e+01 -4.91475977e-02  2.15883684e-01  8.11858222e-01
#   1.42838979e+02  9.63900172e-01  1.12686540e+01  1.02442309e+00
#   4.21038595e-01 -1.14041596e+01 -1.12686540e+01]
# Last dead point: [ 7.17617446e+01 -7.81544798e-02  2.39078661e-01  8.21088062e-01
#   1.45668611e+02  9.83787053e-01  1.10670454e+01  1.00609504e+00
#   4.37663642e-01 -1.10719342e+01 -1.10670454e+01]
# Last dead point: [ 7.58710269e+01 -7.22891277e-02  2.40287318e-01  8.15081662e-01
#   1.37703968e+02  9.25917989e-01  1.09451493e+01  9.95013571e-01
#   4.47869906e-01 -1.10024073e+01 -1.09451493e+01]
# Last dead point: [ 7.18308870e+01 -6.75525146e-02  2.34795479e-01  8.15566640e-01
#   1.46180161e+02  9.80455332e-01  1.08821548e+01  9.89286801e-01
#   4.53188227e-01 -1.10158161e+01 -1.08821548e+01]
# Last dead point: [ 6.42575432e+01 -6.65380529e-02  2.36739804e-01  8.13231084e-01
#   1.63259670e+02  1.09940709e+00  1.07082042e+01  9.73473110e-01
#   4.68022894e-01 -1.08859802e+01 -1.07082042e+01]

# %%
outputBAOR = pypolychord.run_polychord(lnlikeBAO, 6,3, settingsBAOR, unipriorRiess, dumper)
# Out:
# Last dead point: [ 7.48370156e+01 -3.39414201e-02  6.22991693e-01  1.18202215e-02
#   1.25125453e+02  9.55331175e-01  2.77358544e+03  2.52144131e+02
#   0.00000000e+00 -3.24730157e+03 -2.77358544e+03]
# Last dead point: [ 7.40182576e+01  5.01314565e-02  2.00109593e-01  2.49397868e-01
#   1.05188959e+02  9.60988686e-01  1.38944064e+03  1.26312785e+02
#   0.00000000e+00 -5.59756806e+03 -1.38944064e+03]
# Last dead point: [ 7.68224126e+01  3.84543575e-02  1.62950772e-01  4.91654813e-01
#   1.01720154e+02  9.01339134e-01  6.68750381e+02  6.07954892e+01
#   0.00000000e+00 -7.63829504e+02 -6.68750381e+02]
# Last dead point: [ 7.27855313e+01  4.79308428e-02  1.08003457e-01  8.37395729e-01
#   1.41320732e+02  9.59352954e-01  3.16445034e+02  2.87677304e+01
#   0.00000000e+00 -4.24256341e+02 -3.16445034e+02]
# Last dead point: [ 7.55446975e+01 -3.24912860e-02  1.19360081e-01  8.34047469e-01
#   1.27069814e+02  1.03431770e+00  1.50283461e+02  1.36621328e+01
#   0.00000000e+00 -3.97519371e+02 -1.50283461e+02]
# Last dead point: [ 7.44491370e+01  5.32143619e-03  1.05331002e-01  8.31917328e-01
#   1.50703298e+02  1.02119907e+00  8.38270994e+01  7.62064540e+00
#   2.67230682e-13 -1.12544878e+02 -8.38270994e+01]
# Last dead point: [ 7.40028868e+01  9.85912518e-02  9.75724597e-02  7.41785252e-01
#   1.32214728e+02  9.37372082e-01  4.85934157e+01  4.41758325e+00
#   1.11863477e-06 -6.68310363e+01 -4.85934157e+01]
# Last dead point: [ 7.24670193e+01  6.28045096e-02  1.03534103e-01  8.02101785e-01
#   1.53807701e+02  9.76461231e-01  3.32776065e+01  3.02523695e+00
#   4.74330056e-04 -8.56363418e+01 -3.32776065e+01]
# Last dead point: [ 7.46599524e+01  2.95405977e-02  1.07408339e-01  8.21653710e-01
#   1.41660557e+02  9.99423589e-01  2.52539280e+01  2.29581164e+00
#   8.36733950e-03 -3.76028553e+01 -2.52539280e+01]
# Last dead point: [ 7.50839259e+01 -5.67182465e-02  2.42983332e-01  7.85107669e-01
#   1.34240738e+02  9.31247750e-01  1.94501371e+01  1.76819428e+00
#   5.34767088e-02 -2.27905625e+01 -1.94501371e+01]
# Last dead point: [ 7.24911655e+01  9.43497899e-02  9.95962768e-02  7.58486452e-01
#   1.42476095e+02  9.82951230e-01  1.69329047e+01  1.53935498e+00
#   1.09875977e-01 -2.37774308e+01 -1.69329047e+01]
# Last dead point: [ 7.32824879e+01 -5.04846502e-02  2.30985782e-01  7.92957799e-01
#   1.41841099e+02  9.62355418e-01  1.50596610e+01  1.36906009e+00
#   1.79781883e-01 -1.60749693e+01 -1.50596610e+01]
# Last dead point: [ 7.46979143e+01 -2.37967899e-02  1.75100003e-01  8.19013464e-01
#   1.42075470e+02  9.68418101e-01  1.38086907e+01  1.25533552e+00
#   2.43760773e-01 -1.45067937e+01 -1.38086907e+01]
# Last dead point: [ 7.55690944e+01 -4.81675322e-02  1.88060624e-01  8.32437634e-01
#   1.40933942e+02  9.49628702e-01  1.29471811e+01  1.17701646e+00
#   2.96791652e-01 -1.34837156e+01 -1.29471811e+01]
# Last dead point: [ 7.46913482e+01 -7.52452675e-02  2.30437310e-01  8.29055140e-01
#   1.41686779e+02  9.62429574e-01  1.22791737e+01  1.11628852e+00
#   3.43028707e-01 -1.25642630e+01 -1.22791737e+01]
# Last dead point: [ 7.62744604e+01 -3.41105697e-02  2.16172134e-01  7.95958600e-01
#   1.38027340e+02  9.18894788e-01  1.18154009e+01  1.07412736e+00
#   3.77677777e-01 -1.19421116e+01 -1.18154009e+01]
# Last dead point: [ 7.10572613e+01 -8.72263550e-02  2.44842388e-01  8.26484344e-01
#   1.48664943e+02  1.00194074e+00  1.14749324e+01  1.04317567e+00
#   4.04374168e-01 -1.20594592e+01 -1.14749324e+01]
# Last dead point: [ 7.45105723e+01 -6.68250816e-02  2.32218954e-01  8.19552538e-01
#   1.41390728e+02  9.48114820e-01  1.12699018e+01  1.02453652e+00
#   4.20936721e-01 -1.22659305e+01 -1.12699018e+01]
# Last dead point: [ 7.34615673e+01 -7.78777270e-02  2.48512324e-01  8.11835116e-01
#   1.42210433e+02  9.56351458e-01  1.11026055e+01  1.00932777e+00
#   4.34707800e-01 -1.11678659e+01 -1.11026055e+01]
# Last dead point: [ 7.57889358e+01 -5.68912151e-02  2.29066004e-01  8.08408119e-01
#   1.37836793e+02  9.31734444e-01  1.09757289e+01  9.97793534e-01
#   4.45298883e-01 -1.10294110e+01 -1.09757289e+01]
# Last dead point: [ 7.21323501e+01 -7.31415090e-02  2.37421101e-01  8.18138540e-01
#   1.45295694e+02  9.77731979e-01  1.08909950e+01  9.90090454e-01
#   4.52440126e-01 -1.08992237e+01 -1.08909950e+01]
# Last dead point: [ 7.32286071e+01 -7.31111570e-02  2.41359130e-01  8.15285125e-01
#   1.43187902e+02  9.65088004e-01  1.07218875e+01  9.74717042e-01
#   4.66848273e-01 -1.13707624e+01 -1.07218875e+01]

# %%
outputTot = pypolychord.run_polychord(lnlikeTot, 6,3, settingsTot, uniprior, dumper)
# Out:
# Last dead point: [ 7.77766710e+01 -6.35506079e-02  7.65874708e-01  1.92713399e-02
#   1.05491442e+02  9.02624707e-01  4.89406289e+03  1.83298236e+01
#   0.00000000e+00 -1.00000000e+30 -4.89406289e+03]
# Last dead point: [ 6.41440156e+01 -8.95992047e-02  4.25999152e-01  4.56968657e-01
#   1.71869459e+02  9.35191679e-01  2.94868948e+03  1.10437808e+01
#   0.00000000e+00 -4.56912563e+03 -2.94868948e+03]
# Last dead point: [ 7.10071470e+01  6.51532225e-02  1.26882987e-01  5.15350319e-01
#   1.03403313e+02  9.16843436e-01  1.65486140e+03  6.19798278e+00
#   0.00000000e+00 -3.03365693e+03 -1.65486140e+03]
# Last dead point: [ 6.63226975e+01 -4.71484796e-02  3.84199965e-01  5.26181952e-01
#   1.21945069e+02  9.28988907e-01  1.05718130e+03  3.95948053e+00
#   0.00000000e+00 -1.10062818e+03 -1.05718130e+03]
# Last dead point: [ 6.24270574e+01 -1.10998282e-03  1.43548972e-01  7.42838160e-01
#   1.69391947e+02  9.26240204e-01  6.86418503e+02  2.57085582e+00
#   0.00000000e+00 -2.87176989e+03 -6.86418503e+02]
# Last dead point: [ 7.72456735e+01 -8.73373289e-02  1.84293519e-01  8.27243064e-01
#   1.14596371e+02  9.22759176e-01  5.05707462e+02  1.89403544e+00
#   1.11022302e-16 -6.69474333e+02 -5.05707462e+02]
# Last dead point: [ 7.05340295e+01 -9.80318076e-02  1.05186140e-01  9.03988201e-01
#   1.54126196e+02  9.21263708e-01  4.07339594e+02  1.52561646e+00
#   6.54993055e-08 -4.66965703e+02 -4.07339594e+02]
# Last dead point: [ 6.91875457e+01  4.05598009e-02  1.30501294e-01  7.56040227e-01
#   1.35744660e+02  9.53758185e-01  3.49935476e+02  1.31061976e+00
#   4.81563142e-04 -3.67325778e+02 -3.49935476e+02]
# Last dead point: [ 6.67948659e+01  6.49182530e-02  1.08892328e-01  7.64754068e-01
#   1.51867150e+02  9.77626376e-01  3.19919257e+02  1.19819946e+00
#   1.45346290e-02 -3.54838330e+02 -3.19919257e+02]
# Last dead point: [ 6.73383588e+01 -7.30511663e-02  2.84175214e-01  7.59177494e-01
#   1.43255187e+02  1.06723874e+00  3.03039025e+02  1.13497762e+00
#   6.38805798e-02 -3.07177703e+02 -3.03039025e+02]
# Last dead point: [ 6.46336817e+01  9.34455782e-03  1.58930908e-01  7.69763166e-01
#   1.56463218e+02  1.06659012e+00  2.89789665e+02  1.08535455e+00
#   1.61546871e-01 -3.33173459e+02 -2.89789665e+02]
# Last dead point: [ 6.73268934e+01  1.21445854e-02  1.56606477e-01  7.77615778e-01
#   1.48896260e+02  1.05915429e+00  2.82384311e+02  1.05761914e+00
#   2.47591127e-01 -2.91346013e+02 -2.82384311e+02]
# Last dead point: [ 7.22433402e+01 -1.65256437e-02  1.87069012e-01  7.85003722e-01
#   1.41581828e+02  9.32983694e-01  2.76020936e+02  1.03378628e+00
#   3.39130738e-01 -2.80842184e+02 -2.76020936e+02]
# Last dead point: [ 7.12406275e+01 -7.45250329e-02  2.67400875e-01  7.79840201e-01
#   1.45320162e+02  9.73746595e-01  2.70642709e+02  1.01364310e+00
#   4.26321887e-01 -2.86572202e+02 -2.70642709e+02]
# Last dead point: [ 7.25522677e+01 -7.20174886e-02  2.19600969e-01  8.16794242e-01
#   1.43543217e+02  9.69391801e-01  2.67232024e+02  1.00086900e+00
#   4.84488908e-01 -2.81909335e+02 -2.67232024e+02]
# Last dead point: [ 6.77634853e+01 -3.55729260e-02  2.27367139e-01  7.78947204e-01
#   1.52790299e+02  1.04221793e+00  2.64304360e+02  9.89903972e-01
#   5.35128279e-01 -2.72346745e+02 -2.64304360e+02]
# Last dead point: [ 7.03652693e+01 -9.99564297e-02  2.56568004e-01  8.14879024e-01
#   1.44789205e+02  9.84670098e-01  2.62149077e+02  9.81831748e-01
#   5.72328843e-01 -2.64640158e+02 -2.62149077e+02]
# Last dead point: [ 6.91556296e+01 -4.13132330e-02  2.29194120e-01  7.83558018e-01
#   1.49643142e+02  1.00458328e+00  2.60792498e+02  9.76750930e-01
#   5.95541882e-01 -2.62182612e+02 -2.60792498e+02]
# Last dead point: [ 7.16766461e+01 -5.42686476e-02  2.39071473e-01  7.89493877e-01
#   1.44856749e+02  9.73524235e-01  2.59875433e+02  9.73316227e-01
#   6.11095975e-01 -2.60390325e+02 -2.59875433e+02]
# Last dead point: [ 7.19438930e+01 -6.40386134e-02  2.45065354e-01  7.97365727e-01
#   1.43818670e+02  9.84771657e-01  2.59017101e+02  9.70101501e-01
#   6.25527522e-01 -2.59069790e+02 -2.59017101e+02]
# Last dead point: [ 7.25975303e+01 -7.32105546e-02  2.51258746e-01  8.02163929e-01
#   1.41989771e+02  9.64697502e-01  2.58408927e+02  9.67823698e-01
#   6.35668014e-01 -2.59066102e+02 -2.58408927e+02]
# Last dead point: [ 6.95400379e+01 -8.81578039e-02  2.61083484e-01  8.07912924e-01
#   1.48672839e+02  1.00114622e+00  2.57950302e+02  9.66106001e-01
#   6.43263539e-01 -2.59023659e+02 -2.57950302e+02]
# Last dead point: [ 7.06320091e+01 -7.66985550e-02  2.56779519e-01  7.97236584e-01
#   1.45404692e+02  9.82554069e-01  2.57626441e+02  9.64893038e-01
#   6.48598748e-01 -2.57714321e+02 -2.57626441e+02]
# Last dead point: [ 7.15695289e+01 -8.19615789e-02  2.63860907e-01  7.97045026e-01
#   1.43409752e+02  9.72383440e-01  2.57404478e+02  9.64061714e-01
#   6.52241136e-01 -2.58037916e+02 -2.57404478e+02]
# Last dead point: [ 7.02141856e+01 -7.36555083e-02  2.56919354e-01  7.95126949e-01
#   1.46532211e+02  9.96782782e-01  2.57181611e+02  9.63227009e-01
#   6.55886355e-01 -2.57276583e+02 -2.57181611e+02]
# Last dead point: [ 7.07906882e+01 -7.58893549e-02  2.58323171e-01  7.96158548e-01
#   1.45436857e+02  9.82091909e-01  2.57053978e+02  9.62748982e-01
#   6.57968405e-01 -2.57149180e+02 -2.57053978e+02]
# Last dead point: [ 7.06253220e+01 -8.77457245e-02  2.65207370e-01  8.02789109e-01
#   1.46324811e+02  9.89113134e-01  2.56959167e+02  9.62393885e-01
#   6.59512376e-01 -2.57119223e+02 -2.56959167e+02]
# Last dead point: [ 7.10051470e+01 -8.51548462e-02  2.63080325e-01  8.02399914e-01
#   1.44854560e+02  9.83672385e-01  2.56688282e+02  9.61379334e-01
#   6.63910984e-01 -2.56969683e+02 -2.56688282e+02]

# %%
outputTotR = pypolychord.run_polychord(lnlikeTot, 6,3, settingsTotR, unipriorRiess, dumper)
# Out:
# Last dead point: [ 7.66876165e+01 -2.61559042e-02  4.94325603e-01  1.98595557e-01
#   1.36365709e+02  9.50154379e-01  5.71333085e+03  2.13982429e+01
#   0.00000000e+00 -6.52985415e+03 -5.71333085e+03]
# Last dead point: [ 7.32521988e+01 -9.37247569e-03  2.41640728e-01  5.71944865e-01
#   1.64899027e+02  1.02590570e+00  2.91721611e+03  1.09259030e+01
#   0.00000000e+00 -5.77529824e+03 -2.91721611e+03]
# Last dead point: [ 7.50207821e+01 -6.82987291e-02  3.64255554e-01  5.47682171e-01
#   1.15993573e+02  9.37486388e-01  1.35956185e+03  5.09199196e+00
#   0.00000000e+00 -1.93495086e+03 -1.35956185e+03]
# Last dead point: [ 7.39329663e+01  1.88038617e-03  1.79887970e-01  7.09354211e-01
#   1.45901409e+02  9.65743947e-01  7.17409638e+02  2.68692748e+00
#   0.00000000e+00 -8.20270932e+02 -7.17409638e+02]
# Last dead point: [ 7.53460946e+01  1.53485291e-02  1.02294189e-01  8.24509507e-01
#   1.29926153e+02  1.08447531e+00  4.56079967e+02  1.70816467e+00
#   4.58932892e-12 -3.00171582e+03 -4.56079967e+02]
# Last dead point: [ 7.37435413e+01  6.84464349e-02  1.04060784e-01  7.85485073e-01
#   1.51423567e+02  1.05640174e+00  3.69723869e+02  1.38473359e+00
#   3.10588434e-05 -3.87714422e+02 -3.69723869e+02]
# Last dead point: [ 7.29892236e+01 -6.82191704e-02  2.27785096e-01  8.00275006e-01
#   1.47434118e+02  1.00589005e+00  3.25169800e+02  1.21786442e+00
#   8.58562756e-03 -4.48805448e+02 -3.25169800e+02]
# Last dead point: [ 7.28159744e+01  5.59780935e-02  1.19779418e-01  7.75159578e-01
#   1.40422704e+02  1.02724411e+00  3.02587093e+02  1.13328499e+00
#   6.61616400e-02 -3.31323553e+02 -3.02587093e+02]
# Last dead point: [ 7.30492700e+01 -7.75623636e-02  2.22905516e-01  8.06085432e-01
#   1.34320957e+02  9.30636056e-01  2.92488174e+02  1.09546133e+00
#   1.36026031e-01 -3.04254264e+02 -2.92488174e+02]
# Last dead point: [ 7.15591694e+01  7.92332751e-02  1.00356476e-01  7.59100520e-01
#   1.45423055e+02  1.00251969e+00  2.83655967e+02  1.06238190e+00
#   2.31164600e-01 -2.85429520e+02 -2.83655967e+02]
# Last dead point: [ 7.24584417e+01 -2.49337984e-02  1.92931699e-01  7.94117554e-01
#   1.38079112e+02  9.67249045e-01  2.77085198e+02  1.03777228e+00
#   3.22823720e-01 -2.79814023e+02 -2.77085198e+02]
# Last dead point: [ 7.48042425e+01 -7.80348402e-02  2.27152658e-01  8.23426240e-01
#   1.37197372e+02  9.20477794e-01  2.72811424e+02  1.02176563e+00
#   3.90319701e-01 -2.89823516e+02 -2.72811424e+02]
# Last dead point: [ 7.22082250e+01 -9.19154810e-02  2.32285751e-01  8.23834280e-01
#   1.40462912e+02  9.55936755e-01  2.68961028e+02  1.00734467e+00
#   4.54820181e-01 -2.69041041e+02 -2.68961028e+02]
# Last dead point: [ 7.42583233e+01 -5.60068814e-02  2.30652648e-01  8.06713734e-01
#   1.41606562e+02  9.56141671e-01  2.66165732e+02  9.96875399e-01
#   5.02903401e-01 -2.66888998e+02 -2.66165732e+02]
# Last dead point: [ 7.29444826e+01 -9.87815594e-02  2.50242127e-01  8.20847497e-01
#   1.42205493e+02  9.49340572e-01  2.63930691e+02  9.88504462e-01
#   5.41594665e-01 -2.65868729e+02 -2.63930691e+02]
# Last dead point: [ 7.06250271e+01 -8.05847643e-02  2.38645199e-01  8.13956153e-01
#   1.46948786e+02  9.81005008e-01  2.62146322e+02  9.81821430e-01
#   5.72376186e-01 -2.68140455e+02 -2.62146322e+02]
# Last dead point: [ 7.26783776e+01 -7.81535767e-02  2.41881447e-01  8.13118716e-01
#   1.42708048e+02  9.60170410e-01  2.60835123e+02  9.76910572e-01
#   5.94815941e-01 -2.60879718e+02 -2.60835123e+02]
# Last dead point: [ 7.23921698e+01 -8.59233425e-02  2.61718206e-01  8.02231057e-01
#   1.41870261e+02  9.77007435e-01  2.59994171e+02  9.73760940e-01
#   6.09089459e-01 -2.60095070e+02 -2.59994171e+02]
# Last dead point: [ 7.22486859e+01 -6.89370546e-02  2.47503309e-01  7.98294677e-01
#   1.41594085e+02  9.67918881e-01  2.59167617e+02  9.70665231e-01
#   6.23006568e-01 -2.60300042e+02 -2.59167617e+02]
# Last dead point: [ 7.21893265e+01 -9.00829207e-02  2.56850790e-01  8.12009746e-01
#   1.43126957e+02  9.64961969e-01  2.58614590e+02  9.68593971e-01
#   6.32247285e-01 -2.58618078e+02 -2.58614590e+02]
# Last dead point: [ 7.05220736e+01 -9.31274869e-02  2.67006171e-01  8.05215307e-01
#   1.45477313e+02  9.76697371e-01  2.58177450e+02  9.66956743e-01
#   6.39507375e-01 -2.58845586e+02 -2.58177450e+02]
# Last dead point: [ 7.10017947e+01 -5.93500688e-02  2.44642886e-01  7.91489086e-01
#   1.45179598e+02  9.88857248e-01  2.57772548e+02  9.65440253e-01
#   6.46194820e-01 -2.58579539e+02 -2.57772548e+02]
# Last dead point: [ 7.17858005e+01 -8.61979806e-02  2.66205100e-01  7.99685456e-01
#   1.43090960e+02  9.74013221e-01  2.57452627e+02  9.64242049e-01
#   6.51452010e-01 -2.57693435e+02 -2.57452627e+02]
# Last dead point: [ 7.08609894e+01 -8.38573920e-02  2.64233337e-01  7.99276940e-01
#   1.45094829e+02  9.91945879e-01  2.57250114e+02  9.63483572e-01
#   6.54767223e-01 -2.57275633e+02 -2.57250114e+02]
# Last dead point: [ 7.06626210e+01 -7.55777449e-02  2.58892745e-01  7.95152117e-01
#   1.45043060e+02  9.89236224e-01  2.57092280e+02  9.62892436e-01
#   6.57344019e-01 -2.57173840e+02 -2.57092280e+02]
# Last dead point: [ 7.07580760e+01 -8.98052167e-02  2.63257976e-01  8.07148374e-01
#   1.45398970e+02  9.88656380e-01  2.56967629e+02  9.62425577e-01
#   6.59374670e-01 -2.57118820e+02 -2.56967629e+02]
# Last dead point: [ 7.04715949e+01 -9.19655282e-02  2.67410267e-01  8.05297499e-01
#   1.45902353e+02  9.90596397e-01  2.56701150e+02  9.61427528e-01
#   6.63702471e-01 -2.56974484e+02 -2.56701150e+02]

# %%
paramnames = [('h0','H_0 (km s^{-1} Mpc^{-1})'),('ok', '\Omega_k'),('om', '\Omega_m'),('ol', r'\Omega_\Lambda'),('rd','r_d (Mpc)'),('rat','rat'),('L',r'L'),('Ldof',r'L/Dof'),('p','p')]
outputBAO.make_paramnames_files(paramnames)
outputBAOR.make_paramnames_files(paramnames)
outputTot.make_paramnames_files(paramnames)
outputTotR.make_paramnames_files(paramnames)

posteriorBAO = outputBAO.posterior
posteriorBAOR = outputBAOR.posterior
posteriorTot = outputTot.posterior
posteriorTotR = outputTotR.posterior
# Out:
# WARNING:root:outlier fraction 0.09096209912536443
# WARNING:root:outlier fraction 0.10877403846153846
# WARNING:root:outlier fraction 0.06237424547283702
# WARNING:root:outlier fraction 0.03914081145584725
# chains/LCDMBAO_OmkNcS100.txt
# Removed no burn in
# chains/LCDMBAOR_OmkNcS100.txt
# Removed no burn in
# chains/LCDMTot_OmkNcS100.txt
# Removed no burn in
# chains/LCDMTotR_OmkNcS100.txt
# Removed no burn in

# %%
import getdist.plots
# %matplotlib inline
g = plots.get_single_plotter(width_inch=6, ratio=1/1.18)
g.plot_2d([posteriorBAO,posteriorBAOR,posteriorTot,posteriorTotR], ('om','ol'),filled=True)
#g.export('OmOk_fs.pdf')
# Out:
# ((0.05652365786874936, 0.2898116400959386),
#  (0.7357912889209068, 0.8990649024740972))

# %%
g = getdist.plots.getSubplotPlotter()
g.triangle_plot([posteriorBAO,posteriorBAOR,posteriorTot,posteriorTotR], ('h0','om','ol') ,filled=True, legend_labels=[r'BAO',r'BAO + R19',r'CC + BAO + SC',r'CC + SC + BAO + R19'])
#g.export('LCDMrdk_fs.pdf')

# %%
# %matplotlib inline
g = plots.get_single_plotter(width_inch=6, ratio=1/1.18)
g.plot_2d([posteriorBAO,posteriorBAOR,posteriorTot,posteriorTotR], ('h0','om'),filled=True)
g.add_legend([r'BAO',r'BAO + R19',r'CC + BAO + SC',r'CC + SC + BAO + R19'], legend_loc='lower left')
#g.export('Omh0k_fs.pdf')

# %%
# %matplotlib inline
g = plots.get_single_plotter(width_inch=6, ratio=1/1.18)
g.plot_2d([posteriorBAO,posteriorBAOR,posteriorTot,posteriorTotR], ('h0','rd'),filled=True)
g.add_legend([r'BAO',r'BAO + R19',r'CC + SC + BAO',r'CC + SC + BAO + R19'], legend_loc='lower left')
#g.export('h0rdk_fs.pdf')

# %%
# %matplotlib inline
g = plots.get_single_plotter(width_inch=6, ratio=1/1.18)
g.plot_2d([posteriorBAO,posteriorBAOR,posteriorTot,posteriorTotR], ('h0','ok'),filled=True)
g.add_legend([r'BAO',r'BAO + R19',r'CC + SC + BAO',r'CC + SC + BAO + R19'], legend_loc='upper left')
#g.export('h0ok_Omk_fs.pdf')

# %%
# %matplotlib inline
g = plots.get_single_plotter(width_inch=6, ratio=1/1.18)
g.plot_2d([posteriorBAO,posteriorBAOR,posteriorTot,posteriorTotR], ('h0','ok'),filled=True)
#g.add_legend([r'BAO',r'BAO + R19',r'CC + SC + BAO',r'CC + SC + BAO + R19'], legend_loc='upper left')
#g.export('h0ok_Omk_fs.pdf')
# Out:
# ((60.70057883127271, 83.771410136548),
#  (-0.13890338622709153, 0.13850592014023422))

# %%
# %matplotlib inline
g = plots.get_single_plotter(width_inch=6, ratio=1/1.18)
g.plot_2d([posteriorBAO,posteriorBAOR,posteriorTot,posteriorTotR], ('h0','ok'),filled=True)
#g.export('h0ok_Omk_fs.pdf')
# Out:
# ((60.70057883127271, 83.771410136548),
#  (-0.13890338622709153, 0.13850592014023422))

# %%
def get_constraints(samples):
    for i, mean in enumerate(samples.getMeans()):
        upper = samples.confidence(i, upper=True, limfrac=0.05)
        #print("\nupper limit 95 C.L. = %f" % upper)
        lower = samples.confidence(i, upper=False, limfrac=0.05)
        #print("lower limit 95 C.L. = %f" % lower)
        print("%s = %f +/- %f +/- %f" % (samples.parLabel(i),\

        mean, mean - samples.confidence(i, limfrac=0.16),\
        mean - samples.confidence(i, limfrac=0.025)) )
    return
for i in ["BAO","BAOR", "Tot", "TotR"]:
    print(i)
    get_constraints(eval("posterior"+i))
# Out:
# BAO
# H_0 (km s^{-1} Mpc^{-1}) = 71.368953 +/- 5.019894 +/- 6.673367
# \Omega_k = -0.022455 +/- 0.051389 +/- 0.073920
# \Omega_m = 0.185385 +/- 0.047728 +/- 0.087491
# \Omega_\Lambda = 0.808443 +/- 0.020972 +/- 0.038304
# r_d (Mpc) = 148.140612 +/- 10.301046 +/- 14.288939
# rat = 0.998952 +/- 0.070940 +/- 0.095155
# L = 13.623840 +/- 1.588232 +/- 2.400265
# L/Dof = 1.238531 +/- 0.144385 +/- 0.218206
# p = 0.268133 +/- 0.096127 +/- 0.178301
# BAOR
# H_0 (km s^{-1} Mpc^{-1}) = 73.968817 +/- 1.457954 +/- 2.665858
# \Omega_k = -0.026658 +/- 0.046532 +/- 0.067656
# \Omega_m = 0.188413 +/- 0.042007 +/- 0.090922
# \Omega_\Lambda = 0.810126 +/- 0.021516 +/- 0.039317
# r_d (Mpc) = 142.463421 +/- 3.080991 +/- 5.708177
# rat = 0.961019 +/- 0.019986 +/- 0.040265
# L = 13.635102 +/- 1.577019 +/- 2.335823
# L/Dof = 1.239555 +/- 0.143365 +/- 0.212348
# p = 0.266793 +/- 0.092561 +/- 0.176606
# Tot
# H_0 (km s^{-1} Mpc^{-1}) = 70.686810 +/- 1.144414 +/- 2.263346
# \Omega_k = -0.072537 +/- 0.019007 +/- 0.025674
# \Omega_m = 0.249768 +/- 0.015141 +/- 0.032561
# \Omega_\Lambda = 0.799024 +/- 0.010457 +/- 0.018783
# r_d (Mpc) = 145.460446 +/- 2.513111 +/- 4.991599
# rat = 0.988348 +/- 0.018813 +/- 0.035450
# L = 260.140535 +/- 1.764292 +/- 2.638539
# L/Dof = 0.974309 +/- 0.006608 +/- 0.009882
# p = 0.606393 +/- 0.028481 +/- 0.072066
# TotR
# H_0 (km s^{-1} Mpc^{-1}) = 72.140734 +/- 0.857493 +/- 1.781099
# \Omega_k = -0.072597 +/- 0.018395 +/- 0.026094
# \Omega_m = 0.248460 +/- 0.013386 +/- 0.031623
# \Omega_\Lambda = 0.800825 +/- 0.010543 +/- 0.019768
# r_d (Mpc) = 142.896624 +/- 1.970537 +/- 3.783312
# rat = 0.968698 +/- 0.014706 +/- 0.027917
# L = 260.455749 +/- 1.816103 +/- 2.879353
# L/Dof = 0.975490 +/- 0.006802 +/- 0.010784
# p = 0.601036 +/- 0.029072 +/- 0.076997

# %%
def AIC_chi2(chi2, p, n):
    return [chi2+2*p,chi2+2*p+2*p*(p+1)/(n-p-1)]
def BIC_chi2(chi2, p, n):
    return chi2+p*np.log10(n)
L1=260.140535
n1=273
p=6
AIC_chi2(L1,p,n1), BIC_chi2(L1,p,n1)
# Out:
# ([272.140535, 272.4563244736842], 274.75751088224456)

# %%
import getdist.mcsamples
#help(getdist.mcsamples)
for i in ["BAO","BAOR", "Tot", "TotR"]:
    print(eval("posterior"+i).getNumSampleSummaryText())
    print('Marginalised evidence is {} ± {}'.format(eval("output"+i).logZ, eval("output"+i).logZerr))
# Out:
# using 1715 rows, 9 parameters; mean weight 0.2525920506573149, tot weight 433.19536687729504
# Equiv number of single samples (sum w)/max(w): 433.0
# Effective number of weighted samples (sum w)^2/sum(w^2): 643
#
# Marginalised evidence is -26.7167703191202 ± 0.360089937995294
# using 1664 rows, 9 parameters; mean weight 0.25231316620250827, tot weight 419.8491085609737
# Equiv number of single samples (sum w)/max(w): 420.0
# Effective number of weighted samples (sum w)^2/sum(w^2): 630
#
# Marginalised evidence is -25.4479319978604 ± 0.342222314285855
# using 1988 rows, 9 parameters; mean weight 0.12341779181938542, tot weight 245.3545701369382
# Equiv number of single samples (sum w)/max(w): 245.0
# Effective number of weighted samples (sum w)^2/sum(w^2): 657
#
# Marginalised evidence is -277.374939545804 ± 0.412356670465258
# using 2095 rows, 9 parameters; mean weight 0.22082036922509365, tot weight 462.61867352657123
# Equiv number of single samples (sum w)/max(w): 463.0
# Effective number of weighted samples (sum w)^2/sum(w^2): 701
#
# Marginalised evidence is -276.428037604675 ± 0.397148497673586

# %%
#outputBAO

# %%
#outputBAOR

# %%
#outputTot

# %%
#outputTotR
